# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df1 = pd.read_csv("2024 first 4.csv")
df2 = pd.read_csv("kenpom barttorvik 2024.csv")

# %%
df1.head()
# Out:
#    Round  Seed1        Team1       Team2  Seed2
# 0      1     10  Colorado St    Virginia     10
# 1      1     10     Colorado    Boise St     10
# 2      1     16    Grambling  Montana St     16
# 3      1     16       Howard      Wagner     16

# %%
df2.head()
# Out:
#    YEAR CONF  CONF ID  QUAD NO  QUAD ID  TEAM NO  TEAM ID     TEAM  SEED  \
# 0  2024  MAC       17       61        1     1079        2    Akron    14
# 1  2024  SEC       28       63        3     1078        3  Alabama     4
# 2  2024  P12       24       63        3     1077        8  Arizona     2
# 3  2024  SEC       28       64        4     1076       12   Auburn     4
# 4  2024  B12        7       63        3     1075       14   Baylor     3
#
#    ROUND  ...  BADJT RANK  AVG HGT RANK  EFF HGT RANK  EXP RANK  TALENT RANK  \
# 0      0  ...         276           238           199        19          176
# 1      0  ...          13            33             8       156          106
# 2      0  ...          16            50            37       196            7
# 3      0  ...          58            86            76       127           69
# 4      0  ...         274            31            22       304           34
#
#    FT% RANK  OP FT% RANK  PPPO RANK  PPPD RANK  ELITE SOS RANK
# 0       164           47        122         51             249
# 1        10          314          2        263               7
# 2       195          134          8         14              47
# 3        59          284         12          8              69
# 4        97          254         15        155               1
#
# [5 rows x 103 columns]

# %%
for i in df1.index:
    for j in df2.index:
        if df1['Team1'][i] == df2['TEAM'][j]:
            arr1 = df2.iloc[j, 10:]
            break
            
    for k in df2.index:    
        if df1['Team2'][i] == df2['TEAM'][k]:
            arr2 = df2.iloc[k, 10:]
            break
            
    if i == 0:
        df3 = pd.DataFrame(np.subtract(arr1, arr2))
    else:
        df3[i] = np.subtract(arr1, arr2)

data = df3.transpose()
data.head()
# Out:
#   K TEMPO K TEMPO RANK  KADJ T KADJ T RANK   K OFF KO RANK  KADJ O  \
# 0  5.2295          -80  5.8921         -92   9.322    -184    9.96
# 1  2.4845         -141  0.7015         -56    2.44     -30   3.605
# 2 -0.1597           11 -1.2871          69   8.509    -154  14.274
# 3  6.5981         -230  6.2845        -198  8.9186    -165  9.7055
#
#   KADJ O RANK   K DEF KD RANK  ... BADJT RANK AVG HGT RANK EFF HGT RANK  \
# 0        -152  7.0404     115  ...        -94          200          210
# 1         -27   1.077      20  ...        -75          -15         -142
# 2        -209  -3.818    -107  ...         48         -188         -205
# 3        -142  7.8628     203  ...       -200          -19          -35
#
#   EXP RANK TALENT RANK FT% RANK OP FT% RANK PPPO RANK PPPD RANK ELITE SOS RANK
# 0     -279          98     -300         -22      -189       112             -7
# 1      -47         -61      -79         -89       -40        13             10
# 2       55        -288      -98         -42      -149      -119           -232
# 3     -180        -268     -184          68      -168       200             -8
#
# [4 rows x 93 columns]

# %%
final = pd.concat([df1, data], axis=1)

# %%
final.head()
# Out:
#    Round  Seed1        Team1       Team2  Seed2 K TEMPO K TEMPO RANK  KADJ T  \
# 0      1     10  Colorado St    Virginia     10  5.2295          -80  5.8921
# 1      1     10     Colorado    Boise St     10  2.4845         -141  0.7015
# 2      1     16    Grambling  Montana St     16 -0.1597           11 -1.2871
# 3      1     16       Howard      Wagner     16  6.5981         -230  6.2845
#
#   KADJ T RANK   K OFF  ... BADJT RANK AVG HGT RANK EFF HGT RANK EXP RANK  \
# 0         -92   9.322  ...        -94          200          210     -279
# 1         -56    2.44  ...        -75          -15         -142      -47
# 2          69   8.509  ...         48         -188         -205       55
# 3        -198  8.9186  ...       -200          -19          -35     -180
#
#   TALENT RANK FT% RANK OP FT% RANK PPPO RANK PPPD RANK ELITE SOS RANK
# 0          98     -300         -22      -189       112             -7
# 1         -61      -79         -89       -40        13             10
# 2        -288      -98         -42      -149      -119           -232
# 3        -268     -184          68      -168       200             -8
#
# [4 rows x 98 columns]

# %%
final.to_csv('F4 TESTING SET.csv', encoding='utf-8', index=False)
