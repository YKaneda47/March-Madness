# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df1 = pd.read_csv("2024 round 4.csv")
df2 = pd.read_csv("kenpom barttorvik 2024.csv")

# %%
df1.head()
# Out:
#    Round  Seed1        Team1      Team2  Seed2
# 0      4      1  Connecticut    Iowa St      2
# 1      4      1       Purdue  Tennessee      2
# 2      4      1      Houston  Marquette      2
# 3      4      4      Alabama    Arizona      2

# %%
df2.head()
# Out:
#    YEAR CONF  CONF ID  QUAD NO  QUAD ID  TEAM NO  TEAM ID     TEAM  SEED  \
# 0  2024  MAC       17       61        1     1079        2    Akron    14
# 1  2024  SEC       28       63        3     1078        3  Alabama     4
# 2  2024  P12       24       63        3     1077        8  Arizona     2
# 3  2024  SEC       28       64        4     1076       12   Auburn     4
# 4  2024  B12        7       63        3     1075       14   Baylor     3
#
#    ROUND  ...  BADJT RANK  AVG HGT RANK  EFF HGT RANK  EXP RANK  TALENT RANK  \
# 0      0  ...         276           238           199        19          176
# 1      0  ...          13            33             8       156          106
# 2      0  ...          16            50            37       196            7
# 3      0  ...          58            86            76       127           69
# 4      0  ...         274            31            22       304           34
#
#    FT% RANK  OP FT% RANK  PPPO RANK  PPPD RANK  ELITE SOS RANK
# 0       164           47        122         51             249
# 1        10          314          2        263               7
# 2       195          134          8         14              47
# 3        59          284         12          8              69
# 4        97          254         15        155               1
#
# [5 rows x 103 columns]

# %%
for i in df1.index:
    for j in df2.index:
        if df1['Team1'][i] == df2['TEAM'][j]:
            arr1 = df2.iloc[j, 10:]
            break
            
    for k in df2.index:    
        if df1['Team2'][i] == df2['TEAM'][k]:
            arr2 = df2.iloc[k, 10:]
            break
            
    if i == 0:
        df3 = pd.DataFrame(np.subtract(arr1, arr2))
    else:
        df3[i] = np.subtract(arr1, arr2)

data = df3.transpose()
data.head()
# Out:
#   K TEMPO K TEMPO RANK  KADJ T KADJ T RANK   K OFF KO RANK  KADJ O  \
# 0 -1.9397          100 -2.8856         150  12.262     -73  12.744
# 1  -1.605           80 -1.8239          96   6.908     -39   7.967
# 2 -5.1676          228 -5.7093         257   0.613     -11   0.574
# 3  0.7865           -4  0.8082          -7   4.059      -8   4.476
#
#   KADJ O RANK    K DEF KD RANK  ... BADJT RANK AVG HGT RANK EFF HGT RANK  \
# 0         -54   7.7328      25  ...        155          -78          -91
# 1         -25   4.7027      63  ...         90         -221         -153
# 2          -4 -12.3129     -66  ...        263          295          313
# 3          -6  11.1224     237  ...         -3          -17          -29
#
#   EXP RANK TALENT RANK FT% RANK OP FT% RANK PPPO RANK PPPD RANK ELITE SOS RANK
# 0       41         -28     -190          63       -63        20             -5
# 1      122           7      112         107       -40        58             -6
# 2     -127         -17       79        -332        -6       -59              6
# 3      -40          99     -185         180        -6       249            -40
#
# [4 rows x 93 columns]

# %%
final = pd.concat([df1, data], axis=1)

# %%
final.head()
# Out:
#    Round  Seed1        Team1      Team2  Seed2 K TEMPO K TEMPO RANK  KADJ T  \
# 0      4      1  Connecticut    Iowa St      2 -1.9397          100 -2.8856
# 1      4      1       Purdue  Tennessee      2  -1.605           80 -1.8239
# 2      4      1      Houston  Marquette      2 -5.1676          228 -5.7093
# 3      4      4      Alabama    Arizona      2  0.7865           -4  0.8082
#
#   KADJ T RANK   K OFF  ... BADJT RANK AVG HGT RANK EFF HGT RANK EXP RANK  \
# 0         150  12.262  ...        155          -78          -91       41
# 1          96   6.908  ...         90         -221         -153      122
# 2         257   0.613  ...        263          295          313     -127
# 3          -7   4.059  ...         -3          -17          -29      -40
#
#   TALENT RANK FT% RANK OP FT% RANK PPPO RANK PPPD RANK ELITE SOS RANK
# 0         -28     -190          63       -63        20             -5
# 1           7      112         107       -40        58             -6
# 2         -17       79        -332        -6       -59              6
# 3          99     -185         180        -6       249            -40
#
# [4 rows x 98 columns]

# %%
final.to_csv('R8 TESTING SET.csv', encoding='utf-8', index=False)
