# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("Big_Dance_CSV.csv")
df2 = pd.read_csv("kenpom barttorvik 2.csv")

# %%
df1.head()
# Out:
#    Year  Round  Region Number Region Name  Seed1  Score1           Team1  \
# 0  2008      1              1        East      1     113  North Carolina
# 1  2008      1              1        East      2      72       Tennessee
# 2  2008      1              1        East      3      79      Louisville
# 3  2008      1              1        East      4      71   Washington St
# 4  2008      1              1        East      5      68      Notre Dame
#
#             Team2  Score2  Seed2
# 0  Mount St Marys      74     16
# 1        American      57     15
# 2        Boise St      61     14
# 3        Winthrop      40     13
# 4    George Mason      50     12

# %%
df2.head()
# Out:
#    YEAR  CONF  CONF ID  QUAD NO  QUAD ID  TEAM NO  TEAM ID               TEAM  \
# 0  2019  Slnd       29       45        1      807        1  Abilene Christian
# 1  2019   P12       24       47        3      806        9         Arizona St
# 2  2019   SEC       28       45        1      805       12             Auburn
# 3  2019   B12        7       47        3      804       14             Baylor
# 4  2019   OVC       22       48        4      803       15            Belmont
#
#    SEED  ROUND  ...  BADJT RANK  AVG HGT RANK  EFF HGT RANK  EXP RANK  \
# 0    15     64  ...         280           296           280        68
# 1    11     64  ...          57            64           107       287
# 2     5      4  ...         152           208           149        33
# 3     9     32  ...         294           148           164       250
# 4    11     64  ...          33            82            23       255
#
#    TALENT RANK  FT% RANK  OP FT% RANK  PPPO RANK  PPPD RANK  ELITE SOS RANK
# ...

# %%
for i in df1.index:
    for j in df2.index:
        if df1['Year'][i] == df2['YEAR'][j] and df1['Team1'][i] == df2['TEAM'][j]:
            arr1 = df2.iloc[j, 10:]
            break
            
    for k in df2.index:
        if df1['Year'][i] == df2['YEAR'][k] and df1['Team2'][i] == df2['TEAM'][k]:
            arr2 = df2.iloc[k, 10:]
            
    if i == 0:
        df3 = pd.DataFrame(np.subtract(arr1, arr2))
    else:
        df3[i] = np.subtract(arr1, arr2)

data = df3.transpose()
data.head()
# Out:
#   K TEMPO K TEMPO RANK  KADJ T KADJ T RANK   K OFF KO RANK   KADJ O  \
# 0  7.6847         -120  6.6882        -134  14.453    -183  21.6693
# 1  11.793         -309  9.9867        -301   6.174     -64    9.479
# 2 -5.4011          151 -5.5255         142  -3.461      45    3.223
# 3 -4.4331           44 -3.1859          38  10.226    -148  16.5788
# 4  8.4834         -260  7.9935        -263    2.87     -22    4.849
#
#   KADJ O RANK    K DEF KD RANK  ... BADJT RANK AVG HGT RANK EFF HGT RANK  \
# 0        -235    -2.29     -27  ...       -150         -195          -91
# 1         -82  -3.8127     -80  ...       -300         -167         -106
# 2         -38 -11.7407    -184  ...        141          -67         -116
# 3        -215   2.5541      18  ...         33         -200         -172
# 4         -36   0.1584       1  ...       -250         -148         -235
#
#   EXP RANK TALENT RANK FT% RANK OP FT% RANK PPPO RANK PPPD RANK ELITE SOS RANK
# ...

# %%
r = []

for i in df1.index:
    if df1['Score1'][i] > df1['Score2'][i]:
        r.append(1)
    else:
        r.append(0)
        
df1['Result'] = pd.Series(r, index=df1.index)

# %%
seeddiff = []

for i in df1.index:
    seeddiff.append(df1['Seed1'][i] - df1['Seed2'][i])
        
df1['Seed_Diff'] = pd.Series(seeddiff, index=df1.index)

# %%
df1.head()
# Out:
#    Year  Round  Region Number Region Name  Seed1  Score1           Team1  \
# 0  2008      1              1        East      1     113  North Carolina
# 1  2008      1              1        East      2      72       Tennessee
# 2  2008      1              1        East      3      79      Louisville
# 3  2008      1              1        East      4      71   Washington St
# 4  2008      1              1        East      5      68      Notre Dame
#
#             Team2  Score2  Seed2  Result  Seed_Diff
# 0  Mount St Marys      74     16       1        -15
# 1        American      57     15       1        -13
# 2        Boise St      61     14       1        -11
# 3        Winthrop      40     13       1         -9
# 4    George Mason      50     12       1         -7

# %%
df1 = df1.drop(['Year','Region Number', 'Region Name', 'Score1', 'Score2'], axis=1)
df1.head()
# Out:
#    Round  Seed1           Team1           Team2  Seed2  Result  Seed_Diff
# 0      1      1  North Carolina  Mount St Marys     16       1        -15
# 1      1      2       Tennessee        American     15       1        -13
# 2      1      3      Louisville        Boise St     14       1        -11
# 3      1      4   Washington St        Winthrop     13       1         -9
# 4      1      5      Notre Dame    George Mason     12       1         -7

# %%
final = pd.concat([df1, data], axis=1)
final.head()
# Out:
#    Round  Seed1           Team1           Team2  Seed2  Result  Seed_Diff  \
# 0      1      1  North Carolina  Mount St Marys     16       1        -15
# 1      1      2       Tennessee        American     15       1        -13
# 2      1      3      Louisville        Boise St     14       1        -11
# 3      1      4   Washington St        Winthrop     13       1         -9
# 4      1      5      Notre Dame    George Mason     12       1         -7
#
#   K TEMPO K TEMPO RANK  KADJ T  ... BADJT RANK AVG HGT RANK EFF HGT RANK  \
# 0  7.6847         -120  6.6882  ...       -150         -195          -91
# 1  11.793         -309  9.9867  ...       -300         -167         -106
# 2 -5.4011          151 -5.5255  ...        141          -67         -116
# 3 -4.4331           44 -3.1859  ...         33         -200         -172
# 4  8.4834         -260  7.9935  ...       -250         -148         -235
#
#   EXP RANK TALENT RANK FT% RANK OP FT% RANK PPPO RANK PPPD RANK ELITE SOS RANK
# ...

# %%
final.to_csv('FULL TRAINING SET updated.csv', encoding='utf-8', index=False)
