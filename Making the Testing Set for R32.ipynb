# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("2024 round 2 post.csv")
df2 = pd.read_csv("kenpom barttorvik 2024.csv")

# %%
df1.head()
# Out:
#    Round  Seed1        Team1             Team2  Seed2
# 0      2      1  Connecticut  Florida Atlantic      8
# 1      2      2      Iowa St     Washington St      7
# 2      2      3     Illinois          Duquesne     11
# 3      2      4       Auburn               UAB     12
# 4      2      1       Purdue               TCU      9

# %%
df2.head()
# Out:
#    YEAR CONF  CONF ID  QUAD NO  QUAD ID  TEAM NO  TEAM ID     TEAM  SEED  \
# 0  2024  MAC       17       61        1     1079        2    Akron    14
# 1  2024  SEC       28       63        3     1078        3  Alabama     4
# 2  2024  P12       24       63        3     1077        8  Arizona     2
# 3  2024  SEC       28       64        4     1076       12   Auburn     4
# 4  2024  B12        7       63        3     1075       14   Baylor     3
#
#    ROUND  ...  BADJT RANK  AVG HGT RANK  EFF HGT RANK  EXP RANK  TALENT RANK  \
# 0      0  ...         276           238           199        19          176
# 1      0  ...          13            33             8       156          106
# 2      0  ...          16            50            37       196            7
# 3      0  ...          58            86            76       127           69
# 4      0  ...         274            31            22       304           34
#
#    FT% RANK  OP FT% RANK  PPPO RANK  PPPD RANK  ELITE SOS RANK
# 0       164           47        122         51             249
# 1        10          314          2        263               7
# 2       195          134          8         14              47
# 3        59          284         12          8              69
# 4        97          254         15        155               1
#
# [5 rows x 103 columns]

# %%
for i in df1.index:
    for j in df2.index:
        if df1['Team1'][i] == df2['TEAM'][j]:
            arr1 = df2.iloc[j, 10:]
            break
            
    for k in df2.index:    
        if df1['Team2'][i] == df2['TEAM'][k]:
            arr2 = df2.iloc[k, 10:]
            break
            
    if i == 0:
        df3 = pd.DataFrame(np.subtract(arr1, arr2))
    else:
        df3[i] = np.subtract(arr1, arr2)

data = df3.transpose()
data.head()
# Out:
#   K TEMPO K TEMPO RANK  KADJ T KADJ T RANK  K OFF KO RANK KADJ O KADJ O RANK  \
# 0 -2.8113          158 -3.5988         191  5.339     -12  7.647         -15
# 1  1.4924          -76  2.5193        -137 -0.204       3  0.433          -9
# 2  3.7182         -205   3.565        -195  14.03    -184  18.63        -163
# 3  2.2464         -103   1.989         -95  6.282     -47  6.899         -49
# 4 -1.6551           82 -2.2867         112  9.393     -79  9.887         -40
#
#      K DEF KD RANK  ... BADJT RANK AVG HGT RANK EFF HGT RANK EXP RANK  \
# 0  -6.3751    -123  ...        181         -253         -195      279
# 1  -9.5591     -38  ...       -144          100           95      -28
# 2   4.2395     101  ...       -197         -278          -69     -137
# 3 -13.2116    -263  ...        -99         -100          -25        8
# 4   1.0198      23  ...        114           -4          -90      220
#
#   TALENT RANK FT% RANK OP FT% RANK PPPO RANK PPPD RANK ELITE SOS RANK
# 0         -90      -93         -37       -13      -130            -77
# 1         -32       13        -142        -7       -45            -58
# 2        -324     -140          56      -187       100            -74
# 3         -58      -29          83       -47      -266            -55
# 4           2       49         149       -67        25            -20
#
# [5 rows x 93 columns]

# %%
seeddiff = []

for i in df1.index:
    seeddiff.append(df1['Seed1'][i] - df1['Seed2'][i])
        
df1['Seed_Diff'] = pd.Series(seeddiff, index=df1.index)

# %%
final = pd.concat([df1, data], axis=1)

# %%
final.head()
# Out:
#    Round  Seed1        Team1             Team2  Seed2  Seed_Diff K TEMPO  \
# 0      2      1  Connecticut  Florida Atlantic      8         -7 -2.8113
# 1      2      2      Iowa St     Washington St      7         -5  1.4924
# 2      2      3     Illinois          Duquesne     11         -8  3.7182
# 3      2      4       Auburn               UAB     12         -8  2.2464
# 4      2      1       Purdue               TCU      9         -8 -1.6551
#
#   K TEMPO RANK  KADJ T KADJ T RANK  ... BADJT RANK AVG HGT RANK EFF HGT RANK  \
# 0          158 -3.5988         191  ...        181         -253         -195
# 1          -76  2.5193        -137  ...       -144          100           95
# 2         -205   3.565        -195  ...       -197         -278          -69
# 3         -103   1.989         -95  ...        -99         -100          -25
# 4           82 -2.2867         112  ...        114           -4          -90
#
#   EXP RANK TALENT RANK FT% RANK OP FT% RANK PPPO RANK PPPD RANK ELITE SOS RANK
# 0      279         -90      -93         -37       -13      -130            -77
# 1      -28         -32       13        -142        -7       -45            -58
# 2     -137        -324     -140          56      -187       100            -74
# 3        8         -58      -29          83       -47      -266            -55
# 4      220           2       49         149       -67        25            -20
#
# [5 rows x 99 columns]

# %%
final = final.drop(['Seed1', 'Seed2'], axis=1)

# %%
final.to_csv('R32 TESTING SET.csv', encoding='utf-8', index=False)
